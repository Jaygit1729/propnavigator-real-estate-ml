# %%
! pip install dtale
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for dtale from https://files.pythonhosted.org/packages/6e/27/331a2482f4019bd7675c6d9fbae5f80a5b7ce2eb05d5b83eaef49c5d1f7e/dtale-3.17.0-py2.py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/642.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/642.7 kB ? eta -:--:--
#       --------------------------------------- 10.2/642.7 kB ? eta -:--:--
#      -- ---------------------------------- 41.0/642.7 kB 388.9 kB/s eta 0:00:02
#      ------ ----------------------------- 112.6/642.7 kB 819.2 kB/s eta 0:00:01
#      ------------- ------------------------ 235.5/642.7 kB 1.3 MB/s eta 0:00:01
#      --------------------- ---------------- 368.6/642.7 kB 1.8 MB/s eta 0:00:01
#      ------------------------------------ - 624.6/642.7 kB 2.5 MB/s eta 0:00:01
#      -------------------------------------- 642.7/642.7 kB 2.2 MB/s eta 0:00:00
# ...

# %%
import dtale
import pandas as pd

# %%
eda = pd.read_csv(r"C:\Users\Jay Patel\OneDrive\Desktop\CampusX\ML\Projects\PropNavigator\data\fe\featured_properties.csv")


d = dtale.show(eda)
d.open_browser()
# Out:
# C:\Users\Jay Patel\AppData\Roaming\Python\Python311\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# C:\Users\Jay Patel\AppData\Roaming\Python\Python311\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# C:\Users\Jay Patel\AppData\Roaming\Python\Python311\site-packages\dtale\column_analysis.py:511: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# C:\Users\Jay Patel\AppData\Roaming\Python\Python311\site-packages\dtale\column_analysis.py:402: FutureWarning:
#
# pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#
# ...
